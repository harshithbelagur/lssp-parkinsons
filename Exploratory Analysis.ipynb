# %%
import pandas as pd
import glob
import os
from tqdm import tqdm

# %%
df = pd.read_csv('pads-parkinsons-disease-smartwatch-dataset-1.0.0/movement/timeseries/001_CrossArms_LeftWrist.txt', delimiter=',')

# %%
column_names = ['Timestamp', 'Accelerometer_X', 'Accelerometer_Y', 'Accelerometer_Z', 'Gyroscope_X', 'Gyroscope_Y', 'Gyroscope_Z']
df.columns = column_names
df
# Out:
#       Timestamp  Accelerometer_X  Accelerometer_Y  Accelerometer_Z  \
# 0      0.009805         0.002275         0.013380         0.005852
# 1      0.019807         0.001332         0.016225         0.005543
# 2      0.029791         0.001354         0.018107         0.007207
# 3      0.039801         0.001441         0.016004         0.004999
# 4      0.052410         0.000535         0.015800         0.005716
# ...         ...              ...              ...              ...
# 1018  10.185437         0.001216        -0.002975         0.003254
# 1019  10.195432         0.002255         0.001852         0.003247
# 1020  10.205442         0.003365         0.001779         0.001302
# 1021  10.215447         0.001560        -0.000262         0.000336
# 1022  10.225438         0.004596         0.003613         0.000345
#
#       Gyroscope_X  Gyroscope_Y  Gyroscope_Z
# 0       -0.014924    -0.025833     0.004746
# 1       -0.009529    -0.033264     0.005853
# 2       -0.007440    -0.029995     0.009008
# 3       -0.011757    -0.027815     0.017495
# 4       -0.013891    -0.029924     0.022822
# ...           ...          ...          ...
# 1018    -0.007474    -0.013167    -0.019772
# 1019    -0.005365    -0.010989    -0.016599
# 1020    -0.006427    -0.012057    -0.015529
# 1021    -0.004265    -0.013159    -0.021900
# 1022     0.001074    -0.014169    -0.019772
#
# [1023 rows x 7 columns]

# %% [markdown]
# The authors say - At the start of every recording, the smartwatches gave a vibration notification. Therefore, we recommend to cut out approximately the first 0.5 seconds per time series.

# %%
df = df[df['Timestamp']>0.5]
df
# Out:
#       Timestamp  Accelerometer_X  Accelerometer_Y  Accelerometer_Z  \
# 50     0.509774        -0.050591        -0.051501        -0.083111
# 51     0.519775        -0.046225        -0.052912        -0.077044
# 52     0.529748        -0.055828        -0.035950        -0.079996
# 53     0.539816        -0.086870        -0.040002        -0.097529
# 54     0.549893        -0.109431        -0.042224        -0.107230
# ...         ...              ...              ...              ...
# 1018  10.185437         0.001216        -0.002975         0.003254
# 1019  10.195432         0.002255         0.001852         0.003247
# 1020  10.205442         0.003365         0.001779         0.001302
# 1021  10.215447         0.001560        -0.000262         0.000336
# 1022  10.225438         0.004596         0.003613         0.000345
#
#       Gyroscope_X  Gyroscope_Y  Gyroscope_Z
# 50       0.773790     0.420087    -0.436407
# 51       0.854607     0.477981    -0.488896
# 52       0.975002     0.527595    -0.545608
# 53       1.063465     0.565223    -0.600095
# 54       1.147920     0.575992    -0.667155
# ...           ...          ...          ...
# 1018    -0.007474    -0.013167    -0.019772
# 1019    -0.005365    -0.010989    -0.016599
# 1020    -0.006427    -0.012057    -0.015529
# 1021    -0.004265    -0.013159    -0.021900
# 1022     0.001074    -0.014169    -0.019772
#
# [973 rows x 7 columns]

# %% [markdown]
# Other features

# %%
other_features = pd.read_csv('pads-parkinsons-disease-smartwatch-dataset-1.0.0/preprocessed/file_list.csv')
other_features
# Out:
#     resource_type   id study_id                 condition  \
# 0         patient    1     PADS                   Healthy
# 1         patient    2     PADS  Other Movement Disorders
# 2         patient    3     PADS                   Healthy
# 3         patient    4     PADS               Parkinson's
# 4         patient    5     PADS               Parkinson's
# ..            ...  ...      ...                       ...
# 464       patient  465     PADS               Parkinson's
# 465       patient  466     PADS                   Healthy
# 466       patient  467     PADS               Parkinson's
# 467       patient  468     PADS               Parkinson's
# 468       patient  469     PADS               Parkinson's
#
#                                        disease_comment  age_at_diagnosis  age  \
# 0                                                    -                56   56
# 1    Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                    -                45   45
# 3                              IPS akinetic-rigid type                63   67
# 4                              IPS tremordominant type                65   75
# ..                                                 ...               ...  ...
# 464                                     IPS mixed type                62   65
# 465                                                  -                84   84
# 466  Essential Tremor, starting IPS tremordominant ...                55   57
# 467                                     IPS mixed type                73   76
# 468                            IPS tremordominant type                44   54
#
#      height  weight  gender handedness  appearance_in_kinship  \
# 0       173      78    male      right                   True
# 1       193     104    male      right                  False
# 2       170      78  female      right                  False
# 3       161      90  female      right                  False
# 4       172      86    male       left                  False
# ..      ...     ...     ...        ...                    ...
# 464     175      80    male      right                   True
# 465     172      74  female      right                   True
# 466     190     100    male      right                  False
# 467     198     118    male      right                  False
# 468     165      67  female      right                  False
#
#     appearance_in_first_grade_kinship effect_of_alcohol_on_tremor  label
# 0                                True                     Unknown      0
# 1                                 NaN                   No effect      2
# 2                                 NaN                     Unknown      0
# 3                                 NaN                   No effect      1
# 4                                 NaN                     Unknown      1
# ..                                ...                         ...    ...
# 464                             False                   No effect      1
# 465                              True                   No effect      0
# 466                               NaN                 Improvement      1
# 467                               NaN                   No effect      1
# 468                               NaN                     Unknown      1
#
# [469 rows x 15 columns]

# %% [markdown]
# This is the important stuff and the function

# %%
label_counts = other_features['label'].value_counts()

# Display the count of each label
print(label_counts)
# Out:
# label
# 1    276
# 2    114
# 0     79
# Name: count, dtype: int64

# %%
new_columns = ['Accelerometer_X_mean', 'Accelerometer_Y_mean', 'Accelerometer_Z_mean', 'Gyroscope_X_mean', 'Gyroscope_Y_mean', 'Gyroscope_Z_mean', 'Label']

# %%
path = 'pads-parkinsons-disease-smartwatch-dataset-1.0.0/movement/timeseries/'

def get_two_dataframes(event_name):
    file_pattern = f"{path}/*_{event_name}.txt"
    
    file_list = glob.glob(file_pattern)
    first_five_seconds_list = []
    rest_list = []
    
    for filename in tqdm(file_list, desc='Processing files'):
        df = pd.read_csv(filename, delimiter=',')  
        df.columns = column_names
        df = df[(df['Timestamp'] > 0.5) & (df['Timestamp'] < 10.24)]
    
        base_name = os.path.basename(filename)
        unique_identifier = int(base_name.replace(f"_{event_name}.txt", ''))
    
        # Add the unique identifier as a new column
        df['Patient_ID'] = unique_identifier
    
        label_value = other_features.loc[other_features['id'] == unique_identifier, 'label'].iloc[0]
        
        # Assign this label value to the new column in df
        df['Label'] = label_value
    
        #now we will split the first 5 seconds and the rest into two different dataframes
        first_five_seconds_data = df[df['Timestamp'] <= 5]
    
        last_seconds_data = df[df['Timestamp'] > 5]
    
        mean_values = first_five_seconds_data[['Accelerometer_X', 'Accelerometer_Y', 'Accelerometer_Z',
                                 'Gyroscope_X', 'Gyroscope_Y', 'Gyroscope_Z']].mean()
    
        mean_dict = {
        'Accelerometer_X_mean': mean_values['Accelerometer_X'],
        'Accelerometer_Y_mean': mean_values['Accelerometer_Y'],
        'Accelerometer_Z_mean': mean_values['Accelerometer_Z'],
        'Gyroscope_X_mean': mean_values['Gyroscope_X'],
        'Gyroscope_Y_mean': mean_values['Gyroscope_Y'],
        'Gyroscope_Z_mean': mean_values['Gyroscope_Z'],
        'Label': df['Label'].iloc[0],
        'Patient_ID': df['Patient_ID'].iloc[0]
        }
        
        # Convert the dictionary to a DataFrame
        mean_df = pd.DataFrame([mean_dict])
    
        first_five_seconds_list.append(mean_df)
    
        mean_values = last_seconds_data[['Accelerometer_X', 'Accelerometer_Y', 'Accelerometer_Z',
                                 'Gyroscope_X', 'Gyroscope_Y', 'Gyroscope_Z']].mean()
    
        mean_dict = {
        'Accelerometer_X_mean': mean_values['Accelerometer_X'],
        'Accelerometer_Y_mean': mean_values['Accelerometer_Y'],
        'Accelerometer_Z_mean': mean_values['Accelerometer_Z'],
        'Gyroscope_X_mean': mean_values['Gyroscope_X'],
        'Gyroscope_Y_mean': mean_values['Gyroscope_Y'],
        'Gyroscope_Z_mean': mean_values['Gyroscope_Z'],
        'Label': df['Label'].iloc[0],
        'Patient_ID': df['Patient_ID'].iloc[0]
        }
        
        # Convert the dictionary to a DataFrame
        mean_df = pd.DataFrame([mean_dict])
    
        rest_list.append(mean_df)
    
    first_five_seconds_list_df = pd.concat(first_five_seconds_list, ignore_index=True)
    rest_df = pd.concat(rest_list, ignore_index=True)
    return first_five_seconds_list_df, rest_df

# %%
first_five, rest = get_two_dataframes('CrossArms_LeftWrist')
first_five
# Out:
# Processing files: 100%|██████████████████████| 469/469 [00:03<00:00, 153.81it/s]
#      Accelerometer_X_mean  Accelerometer_Y_mean  Accelerometer_Z_mean  \
# 0                0.078888              0.022117              0.083376
# 1                0.048170              0.000354              0.012075
# 2               -0.014036             -0.014067              0.037576
# 3                0.059558              0.036247             -0.010402
# 4               -0.019137             -0.021360              0.018636
# ..                    ...                   ...                   ...
# 464              0.039211             -0.008724              0.023515
# 465              0.047207              0.025210              0.026003
# 466              0.067727             -0.029562              0.009231
# 467              0.042661              0.009035              0.006255
# 468              0.023120             -0.003174              0.027857
#
#      Gyroscope_X_mean  Gyroscope_Y_mean  Gyroscope_Z_mean  Label  Patient_ID
# 0            0.270689          0.223543         -0.559312      2         224
# 1           -0.060996         -0.155827         -0.602306      1         393
# 2           -0.143914          0.052604         -0.433262      1         154
# 3           -0.311721          0.209145         -0.613398      1         458
# 4            0.031197          0.039096         -0.169866      1         331
# ..                ...               ...               ...    ...         ...
# 464         -0.082592          0.360485         -0.323836      1          25
# 465          0.065835          0.007757         -0.572447      0         402
# 466          0.113793          0.506931         -0.216498      1          87
# 467         -0.079779         -0.019240         -0.585376      1         240
# 468          0.221258          0.158535         -0.431520      2         130
#
# [469 rows x 8 columns]

# %%
rest
# Out:
#      Accelerometer_X_mean  Accelerometer_Y_mean  Accelerometer_Z_mean  \
# 0               -0.000233              0.002024              0.000749
# 1               -0.001614              0.003825             -0.000276
# 2                0.002607              0.001212              0.000329
# 3               -0.001622              0.000644              0.000079
# 4               -0.001445              0.001576              0.002075
# ..                    ...                   ...                   ...
# 464             -0.000975             -0.001221              0.000929
# 465             -0.002082              0.004585              0.003324
# 466              0.010538             -0.000418              0.001422
# 467             -0.000611              0.004454              0.003068
# 468              0.000501              0.003783              0.001271
#
#      Gyroscope_X_mean  Gyroscope_Y_mean  Gyroscope_Z_mean  Label  Patient_ID
# 0           -0.001099         -0.000927         -0.001258      2         224
# 1           -0.010429         -0.004088          0.005676      1         393
# 2            0.005582          0.001016          0.001927      1         154
# 3            0.001224         -0.002149          0.002126      1         458
# 4           -0.006636          0.002937         -0.001631      1         331
# ..                ...               ...               ...    ...         ...
# 464          0.005014         -0.007595         -0.007050      1          25
# 465         -0.000350         -0.006961         -0.000974      0         402
# 466         -0.001525          0.002047          0.001241      1          87
# 467         -0.001767         -0.004161          0.003792      1         240
# 468         -0.007913          0.000500         -0.002544      2         130
#
# [469 rows x 8 columns]

# %% [markdown]
# Streaming Stuff - Not needed for now

# %%
import time
import pandas as pd

# Load data from a CSV file
data = combined_df[combined_df['Patient_ID']==1]
data.sort_values('Timestamp', inplace=True)

# Initialize the starting point
start_time = time.time()

# Simulate streaming
for index, row in data.iterrows():
    # Calculate the target time to send the data
    target_time = start_time + row['Timestamp']  # row['timestamp'] is the seconds from the start
    current_time = time.time()
    sleep_time = target_time - current_time
    
    if sleep_time > 0:
        time.sleep(sleep_time)  # Wait until it's time to emit the data

    print(row)  # Replace this with sending the row to your streaming platform
# Out:
# /var/folders/qs/j6xq3rvs41l44b9l0x4ps8k00000gn/T/ipykernel_96407/3305830210.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sort_values('Timestamp', inplace=True)
# Timestamp          0.509774
# Accelerometer_X   -0.050591
# Accelerometer_Y   -0.051501
# Accelerometer_Z   -0.083111
# Gyroscope_X        0.773790
# Gyroscope_Y        0.420087
# Gyroscope_Z       -0.436407
# Patient_ID         1.000000
# Label              0.000000
# Name: 20431, dtype: float64
# Timestamp          0.519775
# Accelerometer_X   -0.046225
# Accelerometer_Y   -0.052912
# Accelerometer_Z   -0.077044
# Gyroscope_X        0.854607
# Gyroscope_Y        0.477981
# Gyroscope_Z       -0.488896
# Patient_ID         1.000000
# Label              0.000000
# Name: 20432, dtype: float64
# Timestamp          0.529748
# Accelerometer_X   -0.055828
# Accelerometer_Y   -0.035950
# Accelerometer_Z   -0.079996
# Gyroscope_X        0.975002
# Gyroscope_Y        0.527595
# Gyroscope_Z       -0.545608
# Patient_ID         1.000000
# Label              0.000000
# Name: 20433, dtype: float64
# Timestamp          0.539816
# Accelerometer_X   -0.086870
# Accelerometer_Y   -0.040002
# Accelerometer_Z   -0.097529
# Gyroscope_X        1.063465
# Gyroscope_Y        0.565223
# Gyroscope_Z       -0.600095
# Patient_ID         1.000000
# Label              0.000000
# Name: 20434, dtype: float64
# Timestamp          0.549893
# Accelerometer_X   -0.109431
# Accelerometer_Y   -0.042224
# Accelerometer_Z   -0.107230
# Gyroscope_X        1.147920
# Gyroscope_Y        0.575992
# Gyroscope_Z       -0.667155
# Patient_ID         1.000000
# Label              0.000000
# Name: 20435, dtype: float64
# Timestamp          0.559768
# Accelerometer_X   -0.097146
# Accelerometer_Y   -0.046210
# Accelerometer_Z   -0.108960
# Gyroscope_X        1.233480
# Gyroscope_Y        0.588761
# Gyroscope_Z       -0.751226
# Patient_ID         1.000000
# Label              0.000000
# Name: 20436, dtype: float64
# Timestamp          0.569723
# Accelerometer_X   -0.075215
# Accelerometer_Y   -0.057991
# Accelerometer_Z   -0.128699
# Gyroscope_X        1.328106
# Gyroscope_Y        0.537473
# Gyroscope_Z       -0.834888
# Patient_ID         1.000000
# Label              0.000000
# Name: 20437, dtype: float64
# Timestamp          0.579751
# Accelerometer_X   -0.062758
# Accelerometer_Y   -0.109129
# Accelerometer_Z   -0.182268
# Gyroscope_X        1.348917
# Gyroscope_Y        0.509053
# Gyroscope_Z       -0.927145
# Patient_ID         1.000000
# Label              0.000000
# Name: 20438, dtype: float64
# Timestamp          0.589725
# Accelerometer_X   -0.088783
# Accelerometer_Y   -0.176027
# Accelerometer_Z   -0.197178
# Gyroscope_X        1.320296
# Gyroscope_Y        0.527135
# Gyroscope_Z       -1.036669
# Patient_ID         1.000000
# Label              0.000000
# Name: 20439, dtype: float64
# Timestamp          0.599798
# Accelerometer_X   -0.139112
# Accelerometer_Y   -0.203831
# Accelerometer_Z   -0.192636
# Gyroscope_X        1.324396
# Gyroscope_Y        0.598722
# Gyroscope_Z       -1.168874
# Patient_ID         1.000000
# Label              0.000000
# Name: 20440, dtype: float64
# Timestamp          0.609709
# Accelerometer_X   -0.167984
# Accelerometer_Y   -0.202692
# Accelerometer_Z   -0.181527
# Gyroscope_X        1.371895
# Gyroscope_Y        0.724931
# Gyroscope_Z       -1.326960
# Patient_ID         1.000000
# Label              0.000000
# Name: 20441, dtype: float64
# Timestamp          0.619712
# Accelerometer_X   -0.175212
# Accelerometer_Y   -0.210503
# Accelerometer_Z   -0.181062
# Gyroscope_X        1.415287
# Gyroscope_Y        0.843363
# Gyroscope_Z       -1.515800
# Patient_ID         1.000000
# Label              0.000000
# Name: 20442, dtype: float64
# Timestamp          0.629762
# Accelerometer_X   -0.178154
# Accelerometer_Y   -0.254659
# Accelerometer_Z   -0.210062
# Gyroscope_X        1.419496
# Gyroscope_Y        0.926169
# Gyroscope_Z       -1.710758
# Patient_ID         1.000000
# Label              0.000000
# Name: 20443, dtype: float64
# Timestamp          0.639711
# Accelerometer_X   -0.179936
# Accelerometer_Y   -0.344846
# Accelerometer_Z   -0.226687
# Gyroscope_X        1.396081
# Gyroscope_Y        0.995874
# Gyroscope_Z       -1.913049
# Patient_ID         1.000000
# Label              0.000000
# Name: 20444, dtype: float64
# Timestamp          0.649742
# Accelerometer_X   -0.191850
# Accelerometer_Y   -0.403107
# Accelerometer_Z   -0.253331
# Gyroscope_X        1.450982
# Gyroscope_Y        1.012860
# Gyroscope_Z       -2.101241
# Patient_ID         1.000000
# Label              0.000000
# Name: 20445, dtype: float64
# Timestamp          0.659625
# Accelerometer_X   -0.215173
# Accelerometer_Y   -0.414761
# Accelerometer_Z   -0.269851
# Gyroscope_X        1.478013
# Gyroscope_Y        1.055036
# Gyroscope_Z       -2.318260
# Patient_ID         1.000000
# Label              0.000000
# Name: 20446, dtype: float64
# Timestamp          0.669686
# Accelerometer_X   -0.249012
# Accelerometer_Y   -0.420552
# Accelerometer_Z   -0.257129
# Gyroscope_X        1.419650
# Gyroscope_Y        1.101788
# Gyroscope_Z       -2.547999
# Patient_ID         1.000000
# Label              0.000000
# Name: 20447, dtype: float64
# Timestamp          0.679690
# Accelerometer_X   -0.258712
# Accelerometer_Y   -0.480385
# Accelerometer_Z   -0.238822
# Gyroscope_X        1.286631
# Gyroscope_Y        1.120609
# Gyroscope_Z       -2.726510
# Patient_ID         1.000000
# Label              0.000000
# Name: 20448, dtype: float64
# Timestamp          0.689688
# Accelerometer_X   -0.246964
# Accelerometer_Y   -0.603704
# Accelerometer_Z   -0.214784
# Gyroscope_X        1.054472
# Gyroscope_Y        1.110097
# Gyroscope_Z       -2.870765
# Patient_ID         1.000000
# Label              0.000000
# Name: 20449, dtype: float64
# Timestamp          0.699658
# Accelerometer_X   -0.234580
# Accelerometer_Y   -0.726744
# Accelerometer_Z   -0.215750
# Gyroscope_X        0.771628
# Gyroscope_Y        1.038141
# Gyroscope_Z       -3.029458
# Patient_ID         1.000000
# Label              0.000000
# Name: 20450, dtype: float64
# Timestamp          0.709696
# Accelerometer_X   -0.223883
# Accelerometer_Y   -0.816289
# Accelerometer_Z   -0.232145
# Gyroscope_X        0.500602
# Gyroscope_Y        0.960845
# Gyroscope_Z       -3.198750
# Patient_ID         1.000000
# Label              0.000000
# Name: 20451, dtype: float64
# Timestamp          0.719682
# Accelerometer_X   -0.241541
# Accelerometer_Y   -0.862772
# Accelerometer_Z   -0.239752
# Gyroscope_X        0.238008
# Gyroscope_Y        0.899584
# Gyroscope_Z       -3.375590
# Patient_ID         1.000000
# Label              0.000000
# Name: 20452, dtype: float64
# Timestamp          0.729664
# Accelerometer_X   -0.288133
# Accelerometer_Y   -0.844495
# Accelerometer_Z   -0.219844
# Gyroscope_X        0.032731
# Gyroscope_Y        0.884578
# Gyroscope_Z       -3.569767
# Patient_ID         1.000000
# Label              0.000000
# Name: 20453, dtype: float64
# Timestamp          0.739839
# Accelerometer_X   -0.327747
# Accelerometer_Y   -0.884372
# Accelerometer_Z   -0.172217
# Gyroscope_X       -0.155797
# Gyroscope_Y        0.899846
# Gyroscope_Z       -3.738655
# Patient_ID         1.000000
# Label              0.000000
# Name: 20454, dtype: float64
# Timestamp          0.749680
# Accelerometer_X   -0.344162
# Accelerometer_Y   -0.922270
# Accelerometer_Z   -0.116416
# Gyroscope_X       -0.414711
# Gyroscope_Y        0.900811
# Gyroscope_Z       -3.891465
# Patient_ID         1.000000
# Label              0.000000
# Name: 20455, dtype: float64
# Timestamp          0.759630
# Accelerometer_X   -0.363361
# Accelerometer_Y   -0.910712
# Accelerometer_Z   -0.043529
# Gyroscope_X       -0.686416
# Gyroscope_Y        0.920453
# Gyroscope_Z       -4.098569
# Patient_ID         1.000000
# Label              0.000000
# Name: 20456, dtype: float64
# Timestamp          0.769692
# Accelerometer_X   -0.411718
# Accelerometer_Y   -0.877223
# Accelerometer_Z    0.013093
# Gyroscope_X       -0.873865
# Gyroscope_Y        0.958707
# Gyroscope_Z       -4.330288
# Patient_ID         1.000000
# Label              0.000000
# Name: 20457, dtype: float64
# Timestamp          0.779873
# Accelerometer_X   -0.438575
# Accelerometer_Y   -0.835097
# Accelerometer_Z    0.054148
# Gyroscope_X       -0.932818
# Gyroscope_Y        0.946685
# Gyroscope_Z       -4.557519
# Patient_ID         1.000000
# Label              0.000000
# Name: 20458, dtype: float64
# Timestamp          0.789657
# Accelerometer_X   -0.439776
# Accelerometer_Y   -0.802912
# Accelerometer_Z    0.074662
# Gyroscope_X       -0.888013
# Gyroscope_Y        0.894104
# Gyroscope_Z       -4.747377
# Patient_ID         1.000000
# Label              0.000000
# Name: 20459, dtype: float64
# Timestamp          0.799638
# Accelerometer_X   -0.470136
# Accelerometer_Y   -0.831317
# Accelerometer_Z    0.095506
# Gyroscope_X       -0.899599
# Gyroscope_Y        0.799829
# Gyroscope_Z       -4.886992
# Patient_ID         1.000000
# Label              0.000000
# Name: 20460, dtype: float64
# Timestamp          0.809635
# Accelerometer_X   -0.509970
# Accelerometer_Y   -0.842163
# Accelerometer_Z    0.159577
# Gyroscope_X       -0.867358
# Gyroscope_Y        0.709906
# Gyroscope_Z       -5.057477
# Patient_ID         1.000000
# Label              0.000000
# Name: 20461, dtype: float64
# Timestamp          0.822044
# Accelerometer_X   -0.544744
# Accelerometer_Y   -0.818903
# Accelerometer_Z    0.217667
# Gyroscope_X       -0.817838
# Gyroscope_Y        0.609132
# Gyroscope_Z       -5.262963
# Patient_ID         1.000000
# Label              0.000000
# Name: 20462, dtype: float64
# Timestamp          0.829813
# Accelerometer_X   -0.554993
# Accelerometer_Y   -0.772417
# Accelerometer_Z    0.270214
# Gyroscope_X       -0.848324
# Gyroscope_Y        0.499250
# Gyroscope_Z       -5.460897
# Patient_ID         1.000000
# Label              0.000000
# Name: 20463, dtype: float64
# Timestamp          0.839598
# Accelerometer_X   -0.545013
# Accelerometer_Y   -0.756124
# Accelerometer_Z    0.349734
# Gyroscope_X       -1.009138
# Gyroscope_Y        0.379222
# Gyroscope_Z       -5.602366
# Patient_ID         1.000000
# Label              0.000000
# Name: 20464, dtype: float64
# Timestamp          0.849570
# Accelerometer_X   -0.537375
# Accelerometer_Y   -0.770370
# Accelerometer_Z    0.404315
# Gyroscope_X       -1.244867
# Gyroscope_Y        0.265409
# Gyroscope_Z       -5.699204
# Patient_ID         1.000000
# Label              0.000000
# Name: 20465, dtype: float64
# Timestamp          0.859580
# Accelerometer_X   -0.532694
# Accelerometer_Y   -0.778606
# Accelerometer_Z    0.430224
# Gyroscope_X       -1.474399
# Gyroscope_Y        0.154278
# Gyroscope_Z       -5.737630
# Patient_ID         1.000000
# Label              0.000000
# Name: 20466, dtype: float64
# Timestamp          0.869666
# Accelerometer_X   -0.546679
# Accelerometer_Y   -0.744818
# Accelerometer_Z    0.465212
# Gyroscope_X       -1.645712
# Gyroscope_Y        0.102393
# Gyroscope_Z       -5.775421
# Patient_ID         1.000000
# Label              0.000000
# Name: 20467, dtype: float64
# Timestamp          0.879591
# Accelerometer_X   -0.601568
# Accelerometer_Y   -0.724617
# Accelerometer_Z    0.522623
# Gyroscope_X       -1.738175
# Gyroscope_Y        0.083896
# Gyroscope_Z       -5.854915
# Patient_ID         1.000000
# Label              0.000000
# Name: 20468, dtype: float64
# Timestamp          0.889635
# Accelerometer_X   -0.654635
# Accelerometer_Y   -0.662986
# Accelerometer_Z    0.569572
# Gyroscope_X       -1.764288
# Gyroscope_Y        0.035135
# Gyroscope_Z       -5.908763
# Patient_ID         1.000000
# Label              0.000000
# Name: 20469, dtype: float64
# Timestamp          0.899561
# Accelerometer_X   -0.662284
# Accelerometer_Y   -0.544050
# Accelerometer_Z    0.589229
# Gyroscope_X       -1.762875
# Gyroscope_Y       -0.114964
# Gyroscope_Z       -5.964098
# Patient_ID         1.000000
# Label              0.000000
# Name: 20470, dtype: float64
# Timestamp          0.909582
# Accelerometer_X   -0.632275
# Accelerometer_Y   -0.473053
# Accelerometer_Z    0.602193
# Gyroscope_X       -1.717698
# Gyroscope_Y       -0.262635
# Gyroscope_Z       -6.024791
# Patient_ID         1.000000
# Label              0.000000
# Name: 20471, dtype: float64
# Timestamp          0.919526
# Accelerometer_X   -0.623062
# Accelerometer_Y   -0.412422
# Accelerometer_Z    0.606990
# Gyroscope_X       -1.718831
# Gyroscope_Y       -0.377165
# Gyroscope_Z       -6.042105
# Patient_ID         1.000000
# Label              0.000000
# Name: 20472, dtype: float64
# Timestamp          0.929612
# Accelerometer_X   -0.632233
# Accelerometer_Y   -0.338950
# Accelerometer_Z    0.611986
# Gyroscope_X       -1.804605
# Gyroscope_Y       -0.482107
# Gyroscope_Z       -5.987183
# Patient_ID         1.000000
# Label              0.000000
# Name: 20473, dtype: float64
# Timestamp          0.939520
# Accelerometer_X   -0.622764
# Accelerometer_Y   -0.296291
# Accelerometer_Z    0.639701
# Gyroscope_X       -1.912103
# Gyroscope_Y       -0.559044
# Gyroscope_Z       -5.887808
# Patient_ID         1.000000
# Label              0.000000
# Name: 20474, dtype: float64
# Timestamp          0.949621
# Accelerometer_X   -0.624779
# Accelerometer_Y   -0.249468
# Accelerometer_Z    0.671129
# Gyroscope_X       -2.012557
# Gyroscope_Y       -0.591928
# Gyroscope_Z       -5.767475
# Patient_ID         1.000000
# Label              0.000000
# Name: 20475, dtype: float64
# Timestamp          0.959551
# Accelerometer_X   -0.647594
# Accelerometer_Y   -0.192664
# Accelerometer_Z    0.666951
# Gyroscope_X       -2.118426
# Gyroscope_Y       -0.622554
# Gyroscope_Z       -5.628027
# Patient_ID         1.000000
# Label              0.000000
# Name: 20476, dtype: float64
# Timestamp          0.969654
# Accelerometer_X   -0.648141
# Accelerometer_Y   -0.122049
# Accelerometer_Z    0.657526
# Gyroscope_X       -2.152440
# Gyroscope_Y       -0.695347
# Gyroscope_Z       -5.485171
# Patient_ID         1.000000
# Label              0.000000
# Name: 20477, dtype: float64
# Timestamp          0.979558
# Accelerometer_X   -0.629954
# Accelerometer_Y   -0.053483
# Accelerometer_Z    0.637164
# Gyroscope_X       -2.062737
# Gyroscope_Y       -0.758556
# Gyroscope_Z       -5.333966
# Patient_ID         1.000000
# Label              0.000000
# Name: 20478, dtype: float64
# Timestamp          0.989565
# Accelerometer_X   -0.614315
# Accelerometer_Y   -0.002651
# Accelerometer_Z    0.609770
# Gyroscope_X       -1.868580
# Gyroscope_Y       -0.808009
# Gyroscope_Z       -5.168048
# Patient_ID         1.000000
# Label              0.000000
# Name: 20479, dtype: float64
# Timestamp          0.999545
# Accelerometer_X   -0.607354
# Accelerometer_Y    0.034115
# Accelerometer_Z    0.586478
# Gyroscope_X       -1.640308
# Gyroscope_Y       -0.846635
# Gyroscope_Z       -5.017099
# Patient_ID         1.000000
# Label              0.000000
# Name: 20480, dtype: float64
# Timestamp          1.009511
# Accelerometer_X   -0.595658
# Accelerometer_Y    0.047694
# Accelerometer_Z    0.611580
# Gyroscope_X       -1.461112
# Gyroscope_Y       -0.886747
# Gyroscope_Z       -4.870353
# Patient_ID         1.000000
# Label              0.000000
# Name: 20481, dtype: float64
# Timestamp          1.019561
# Accelerometer_X   -0.603874
# Accelerometer_Y    0.068773
# Accelerometer_Z    0.645175
# Gyroscope_X       -1.330952
# Gyroscope_Y       -0.925313
# Gyroscope_Z       -4.748018
# Patient_ID         1.000000
# Label              0.000000
# Name: 20482, dtype: float64
# Timestamp          1.029557
# Accelerometer_X   -0.612441
# Accelerometer_Y    0.078772
# Accelerometer_Z    0.664405
# Gyroscope_X       -1.232851
# Gyroscope_Y       -0.950439
# Gyroscope_Z       -4.650184
# Patient_ID         1.000000
# Label              0.000000
# Name: 20483, dtype: float64
# Timestamp          1.039499
# Accelerometer_X   -0.609269
# Accelerometer_Y    0.094586
# Accelerometer_Z    0.693670
# Gyroscope_X       -1.124192
# Gyroscope_Y       -0.959492
# Gyroscope_Z       -4.557775
# Patient_ID         1.000000
# Label              0.000000
# Name: 20484, dtype: float64
# Timestamp          1.049555
# Accelerometer_X   -0.610542
# Accelerometer_Y    0.085939
# Accelerometer_Z    0.715526
# Gyroscope_X       -1.001382
# Gyroscope_Y       -1.003665
# Gyroscope_Z       -4.459834
# Patient_ID         1.000000
# Label              0.000000
# Name: 20485, dtype: float64
# Timestamp          1.059516
# Accelerometer_X   -0.615067
# Accelerometer_Y    0.065874
# Accelerometer_Z    0.717261
# Gyroscope_X       -0.861183
# Gyroscope_Y       -1.090348
# Gyroscope_Z       -4.348880
# Patient_ID         1.000000
# Label              0.000000
# Name: 20486, dtype: float64
# Timestamp          1.069628
# Accelerometer_X   -0.623759
# Accelerometer_Y    0.047201
# Accelerometer_Z    0.708008
# Gyroscope_X       -0.771017
# Gyroscope_Y       -1.195549
# Gyroscope_Z       -4.233522
# Patient_ID         1.000000
# Label              0.000000
# Name: 20487, dtype: float64
# Timestamp          1.079625
# Accelerometer_X   -0.640576
# Accelerometer_Y    0.027925
# Accelerometer_Z    0.702668
# Gyroscope_X       -0.704279
# Gyroscope_Y       -1.309439
# Gyroscope_Z       -4.112780
# Patient_ID         1.000000
# Label              0.000000
# Name: 20488, dtype: float64
# Timestamp          1.089597
# Accelerometer_X   -0.638055
# Accelerometer_Y    0.019958
# Accelerometer_Z    0.681192
# Gyroscope_X       -0.637240
# Gyroscope_Y       -1.459672
# Gyroscope_Z       -3.992864
# Patient_ID         1.000000
# Label              0.000000
# Name: 20489, dtype: float64
# Timestamp          1.099594
# Accelerometer_X   -0.613503
# Accelerometer_Y    0.032568
# Accelerometer_Z    0.674745
# Gyroscope_X       -0.517906
# Gyroscope_Y       -1.605300
# Gyroscope_Z       -3.881514
# Patient_ID         1.000000
# Label              0.000000
# Name: 20490, dtype: float64
# Timestamp          1.109592
# Accelerometer_X   -0.595230
# Accelerometer_Y    0.078491
# Accelerometer_Z    0.653591
# Gyroscope_X       -0.391134
# Gyroscope_Y       -1.747644
# Gyroscope_Z       -3.768066
# Patient_ID         1.000000
# Label              0.000000
# Name: 20491, dtype: float64
# Timestamp          1.119690
# Accelerometer_X   -0.587811
# Accelerometer_Y    0.108804
# Accelerometer_Z    0.616107
# Gyroscope_X       -0.326459
# Gyroscope_Y       -1.873242
# Gyroscope_Z       -3.639809
# Patient_ID         1.000000
# Label              0.000000
# Name: 20492, dtype: float64
# Timestamp          1.129877
# Accelerometer_X   -0.591427
# Accelerometer_Y    0.106739
# Accelerometer_Z    0.587954
# Gyroscope_X       -0.349601
# Gyroscope_Y       -1.970524
# Gyroscope_Z       -3.495739
# Patient_ID         1.000000
# Label              0.000000
# Name: 20493, dtype: float64
# Timestamp          1.142314
# Accelerometer_X   -0.618399
# Accelerometer_Y    0.095184
# Accelerometer_Z    0.563894
# Gyroscope_X       -0.377538
# Gyroscope_Y       -1.991170
# Gyroscope_Z       -3.385098
# Patient_ID         1.000000
# Label              0.000000
# Name: 20494, dtype: float64
# Timestamp          1.150814
# Accelerometer_X   -0.641104
# Accelerometer_Y    0.107885
# Accelerometer_Z    0.527856
# Gyroscope_X       -0.290341
# Gyroscope_Y       -1.994859
# Gyroscope_Z       -3.270396
# Patient_ID         1.000000
# Label              0.000000
# Name: 20495, dtype: float64
# Timestamp          1.161178
# Accelerometer_X   -0.637374
# Accelerometer_Y    0.144936
# Accelerometer_Z    0.482482
# Gyroscope_X       -0.123235
# Gyroscope_Y       -1.980820
# Gyroscope_Z       -3.154803
# Patient_ID         1.000000
# Label              0.000000
# Name: 20496, dtype: float64
# Timestamp          1.169756
# Accelerometer_X   -0.618875
# Accelerometer_Y    0.173662
# Accelerometer_Z    0.451209
# Gyroscope_X        0.070616
# Gyroscope_Y       -1.976138
# Gyroscope_Z       -3.032794
# Patient_ID         1.000000
# Label              0.000000
# Name: 20497, dtype: float64
# Timestamp          1.179446
# Accelerometer_X   -0.605077
# Accelerometer_Y    0.196992
# Accelerometer_Z    0.416255
# Gyroscope_X        0.281631
# Gyroscope_Y       -1.985149
# Gyroscope_Z       -2.903274
# Patient_ID         1.000000
# Label              0.000000
# Name: 20498, dtype: float64
# Timestamp          1.189448
# Accelerometer_X   -0.592200
# Accelerometer_Y    0.227740
# Accelerometer_Z    0.368861
# Gyroscope_X        0.481814
# Gyroscope_Y       -1.977095
# Gyroscope_Z       -2.767480
# Patient_ID         1.000000
# Label              0.000000
# Name: 20499, dtype: float64
# Timestamp          1.199456
# Accelerometer_X   -0.587523
# Accelerometer_Y    0.255046
# Accelerometer_Z    0.346150
# Gyroscope_X        0.604935
# Gyroscope_Y       -1.948167
# Gyroscope_Z       -2.620078
# Patient_ID         1.000000
# Label              0.000000
# Name: 20500, dtype: float64
# Timestamp          1.209925
# Accelerometer_X   -0.586041
# Accelerometer_Y    0.270307
# Accelerometer_Z    0.318129
# Gyroscope_X        0.634171
# Gyroscope_Y       -1.930547
# Gyroscope_Z       -2.460854
# Patient_ID         1.000000
# Label              0.000000
# Name: 20501, dtype: float64
# Timestamp          1.219789
# Accelerometer_X   -0.576493
# Accelerometer_Y    0.258318
# Accelerometer_Z    0.281513
# Gyroscope_X        0.593644
# Gyroscope_Y       -1.995788
# Gyroscope_Z       -2.304232
# Patient_ID         1.000000
# Label              0.000000
# Name: 20502, dtype: float64
# Timestamp          1.229459
# Accelerometer_X   -0.549145
# Accelerometer_Y    0.229382
# Accelerometer_Z    0.252235
# Gyroscope_X        0.474845
# Gyroscope_Y       -2.020968
# Gyroscope_Z       -2.141440
# Patient_ID         1.000000
# Label              0.000000
# Name: 20503, dtype: float64
# Timestamp          1.239566
# Accelerometer_X   -0.541089
# Accelerometer_Y    0.216925
# Accelerometer_Z    0.247124
# Gyroscope_X        0.354264
# Gyroscope_Y       -1.949126
# Gyroscope_Z       -2.004771
# Patient_ID         1.000000
# Label              0.000000
# Name: 20504, dtype: float64
# Timestamp          1.249618
# Accelerometer_X   -0.563194
# Accelerometer_Y    0.198629
# Accelerometer_Z    0.244392
# Gyroscope_X        0.313883
# Gyroscope_Y       -1.900053
# Gyroscope_Z       -1.854201
# Patient_ID         1.000000
# Label              0.000000
# Name: 20505, dtype: float64
# Timestamp          1.259613
# Accelerometer_X   -0.558478
# Accelerometer_Y    0.202906
# Accelerometer_Z    0.213139
# Gyroscope_X        0.363638
# Gyroscope_Y       -1.910091
# Gyroscope_Z       -1.699066
# Patient_ID         1.000000
# Label              0.000000
# Name: 20506, dtype: float64
# Timestamp          1.269661
# Accelerometer_X   -0.534522
# Accelerometer_Y    0.205779
# Accelerometer_Z    0.168050
# Gyroscope_X        0.430493
# Gyroscope_Y       -1.916916
# Gyroscope_Z       -1.557770
# Patient_ID         1.000000
# Label              0.000000
# Name: 20507, dtype: float64
# Timestamp          1.279593
# Accelerometer_X   -0.521614
# Accelerometer_Y    0.201084
# Accelerometer_Z    0.130424
# Gyroscope_X        0.443003
# Gyroscope_Y       -1.935903
# Gyroscope_Z       -1.414232
# Patient_ID         1.000000
# Label              0.000000
# Name: 20508, dtype: float64
# Timestamp          1.289635
# Accelerometer_X   -0.500970
# Accelerometer_Y    0.165679
# Accelerometer_Z    0.082155
# Gyroscope_X        0.367936
# Gyroscope_Y       -1.949161
# Gyroscope_Z       -1.271733
# Patient_ID         1.000000
# Label              0.000000
# Name: 20509, dtype: float64
# Timestamp          1.299571
# Accelerometer_X   -0.468175
# Accelerometer_Y    0.130453
# Accelerometer_Z    0.053481
# Gyroscope_X        0.278977
# Gyroscope_Y       -1.955166
# Gyroscope_Z       -1.143081
# Patient_ID         1.000000
# Label              0.000000
# Name: 20510, dtype: float64
# Timestamp          1.309610
# Accelerometer_X   -0.431414
# Accelerometer_Y    0.131536
# Accelerometer_Z    0.036219
# Gyroscope_X        0.244387
# Gyroscope_Y       -1.943838
# Gyroscope_Z       -1.036891
# Patient_ID         1.000000
# Label              0.000000
# Name: 20511, dtype: float64
# Timestamp          1.319558
# Accelerometer_X   -0.410435
# Accelerometer_Y    0.139585
# Accelerometer_Z    0.014460
# Gyroscope_X        0.212327
# Gyroscope_Y       -1.838705
# Gyroscope_Z       -0.963184
# Patient_ID         1.000000
# Label              0.000000
# Name: 20512, dtype: float64
# Timestamp          1.329571
# Accelerometer_X   -0.403328
# Accelerometer_Y    0.151482
# Accelerometer_Z    0.012415
# Gyroscope_X        0.168234
# Gyroscope_Y       -1.682703
# Gyroscope_Z       -0.929106
# Patient_ID         1.000000
# Label              0.000000
# Name: 20513, dtype: float64
# Timestamp          1.339588
# Accelerometer_X   -0.385926
# Accelerometer_Y    0.126084
# Accelerometer_Z   -0.049613
# Gyroscope_X        0.152152
# Gyroscope_Y       -1.562716
# Gyroscope_Z       -0.882064
# Patient_ID         1.000000
# Label              0.000000
# Name: 20514, dtype: float64
# Timestamp          1.355365
# Accelerometer_X   -0.352638
# Accelerometer_Y    0.083469
# Accelerometer_Z   -0.124717
# Gyroscope_X        0.166968
# Gyroscope_Y       -1.439209
# Gyroscope_Z       -0.826569
# Patient_ID         1.000000
# Label              0.000000
# Name: 20515, dtype: float64
# Timestamp          1.388924
# Accelerometer_X   -0.330134
# Accelerometer_Y    0.059874
# Accelerometer_Z   -0.183924
# Gyroscope_X        0.182001
# Gyroscope_Y       -1.345549
# Gyroscope_Z       -0.762383
# Patient_ID         1.000000
# Label              0.000000
# Name: 20516, dtype: float64
# Timestamp          1.389339
# Accelerometer_X   -0.304523
# Accelerometer_Y    0.021199
# Accelerometer_Z   -0.216144
# Gyroscope_X        0.181878
# Gyroscope_Y       -1.231577
# Gyroscope_Z       -0.683442
# Patient_ID         1.000000
# Label              0.000000
# Name: 20517, dtype: float64
# Timestamp          1.389371
# Accelerometer_X   -0.273348
# Accelerometer_Y   -0.000379
# Accelerometer_Z   -0.219596
# Gyroscope_X        0.179471
# Gyroscope_Y       -1.095275
# Gyroscope_Z       -0.616333
# Patient_ID         1.000000
# Label              0.000000
# Name: 20518, dtype: float64
# Timestamp          1.390505
# Accelerometer_X   -0.247006
# Accelerometer_Y   -0.008455
# Accelerometer_Z   -0.260709
# Gyroscope_X        0.141023
# Gyroscope_Y       -0.982913
# Gyroscope_Z       -0.566040
# Patient_ID         1.000000
# Label              0.000000
# Name: 20519, dtype: float64
# Timestamp          1.399540
# Accelerometer_X   -0.206721
# Accelerometer_Y   -0.021533
# Accelerometer_Z   -0.304859
# Gyroscope_X        0.099574
# Gyroscope_Y       -0.898285
# Gyroscope_Z       -0.504934
# Patient_ID         1.000000
# Label              0.000000
# Name: 20520, dtype: float64
# Timestamp          1.409583
# Accelerometer_X   -0.177683
# Accelerometer_Y   -0.035157
# Accelerometer_Z   -0.340407
# Gyroscope_X        0.006049
# Gyroscope_Y       -0.823024
# Gyroscope_Z       -0.493671
# Patient_ID         1.000000
# Label              0.000000
# Name: 20521, dtype: float64
# Timestamp          1.419241
# Accelerometer_X   -0.152682
# Accelerometer_Y   -0.021392
# Accelerometer_Z   -0.335305
# Gyroscope_X        0.026600
# Gyroscope_Y       -0.763261
# Gyroscope_Z       -0.398459
# Patient_ID         1.000000
# Label              0.000000
# Name: 20522, dtype: float64
# Timestamp          1.429269
# Accelerometer_X   -0.118612
# Accelerometer_Y   -0.025598
# Accelerometer_Z   -0.314717
# Gyroscope_X        0.043538
# Gyroscope_Y       -0.639701
# Gyroscope_Z       -0.338716
# Patient_ID         1.000000
# Label              0.000000
# Name: 20523, dtype: float64
# Timestamp          1.439692
# Accelerometer_X   -0.109938
# Accelerometer_Y   -0.009295
# Accelerometer_Z   -0.281045
# Gyroscope_X        0.012829
# Gyroscope_Y       -0.571903
# Gyroscope_Z       -0.257331
# Patient_ID         1.000000
# Label              0.000000
# Name: 20524, dtype: float64
# Timestamp          1.449486
# Accelerometer_X   -0.080642
# Accelerometer_Y   -0.023582
# Accelerometer_Z   -0.272471
# Gyroscope_X       -0.083738
# Gyroscope_Y       -0.544144
# Gyroscope_Z       -0.173515
# Patient_ID         1.000000
# Label              0.000000
# Name: 20525, dtype: float64
# Timestamp          1.459506
# Accelerometer_X   -0.063879
# Accelerometer_Y   -0.056455
# Accelerometer_Z   -0.281380
# Gyroscope_X       -0.200607
# Gyroscope_Y       -0.511256
# Gyroscope_Z       -0.096090
# Patient_ID         1.000000
# Label              0.000000
# Name: 20526, dtype: float64
# Timestamp          1.469554
# Accelerometer_X   -0.067023
# Accelerometer_Y   -0.065807
# Accelerometer_Z   -0.277777
# Gyroscope_X       -0.284309
# Gyroscope_Y       -0.486686
# Gyroscope_Z       -0.021823
# Patient_ID         1.000000
# Label              0.000000
# Name: 20527, dtype: float64
# Timestamp          1.479647
# Accelerometer_X   -0.068682
# Accelerometer_Y   -0.043289
# Accelerometer_Z   -0.265514
# Gyroscope_X       -0.312660
# Gyroscope_Y       -0.438278
# Gyroscope_Z        0.039499
# Patient_ID         1.000000
# Label              0.000000
# Name: 20528, dtype: float64
# Timestamp          1.489119
# Accelerometer_X   -0.078674
# Accelerometer_Y   -0.011872
# Accelerometer_Z   -0.243751
# Gyroscope_X       -0.295235
# Gyroscope_Y       -0.377691
# Gyroscope_Z        0.109212
# Patient_ID         1.000000
# Label              0.000000
# Name: 20529, dtype: float64
# Timestamp          1.499184
# Accelerometer_X   -0.094824
# Accelerometer_Y    0.008003
# Accelerometer_Z   -0.229963
# Gyroscope_X       -0.307750
# Gyroscope_Y       -0.314058
# Gyroscope_Z        0.187425
# Patient_ID         1.000000
# Label              0.000000
# Name: 20530, dtype: float64
# Timestamp          1.509133
# Accelerometer_X   -0.114186
# Accelerometer_Y    0.005153
# Accelerometer_Z   -0.217162
# Gyroscope_X       -0.372583
# Gyroscope_Y       -0.248700
# Gyroscope_Z        0.264601
# Patient_ID         1.000000
# Label              0.000000
# Name: 20531, dtype: float64
# Timestamp          1.519141
# Accelerometer_X   -0.145799
# Accelerometer_Y   -0.006100
# Accelerometer_Z   -0.198603
# Gyroscope_X       -0.448221
# Gyroscope_Y       -0.168440
# Gyroscope_Z        0.343811
# Patient_ID         1.000000
# Label              0.000000
# Name: 20532, dtype: float64
# Timestamp          1.529149
# Accelerometer_X   -0.182131
# Accelerometer_Y    0.006638
# Accelerometer_Z   -0.177349
# Gyroscope_X       -0.492971
# Gyroscope_Y       -0.086723
# Gyroscope_Z        0.441052
# Patient_ID         1.000000
# Label              0.000000
# Name: 20533, dtype: float64
# Timestamp          1.539129
# Accelerometer_X   -0.220067
# Accelerometer_Y    0.033885
# Accelerometer_Z   -0.170004
# Gyroscope_X       -0.505727
# Gyroscope_Y       -0.006775
# Gyroscope_Z        0.552093
# Patient_ID         1.000000
# Label              0.000000
# Name: 20534, dtype: float64
# Timestamp          1.549128
# Accelerometer_X   -0.257849
# Accelerometer_Y    0.085811
# Accelerometer_Z   -0.163969
# Gyroscope_X       -0.480094
# Gyroscope_Y        0.077752
# Gyroscope_Z        0.664141
# Patient_ID         1.000000
# Label              0.000000
# Name: 20535, dtype: float64
# Timestamp          1.559113
# Accelerometer_X   -0.309112
# Accelerometer_Y    0.140289
# Accelerometer_Z   -0.155416
# Gyroscope_X       -0.420603
# Gyroscope_Y        0.197833
# Gyroscope_Z        0.779124
# Patient_ID         1.000000
# Label              0.000000
# Name: 20536, dtype: float64
# Timestamp          1.569169
# Accelerometer_X   -0.367468
# Accelerometer_Y    0.203519
# Accelerometer_Z   -0.131728
# Gyroscope_X       -0.337785
# Gyroscope_Y        0.336278
# Gyroscope_Z        0.895031
# Patient_ID         1.000000
# Label              0.000000
# Name: 20537, dtype: float64
# Timestamp          1.579121
# Accelerometer_X   -0.418305
# Accelerometer_Y    0.254302
# Accelerometer_Z   -0.097638
# Gyroscope_X       -0.255199
# Gyroscope_Y        0.503567
# Gyroscope_Z        1.009691
# Patient_ID         1.000000
# Label              0.000000
# Name: 20538, dtype: float64
# Timestamp          1.589188
# Accelerometer_X   -0.466492
# Accelerometer_Y    0.284606
# Accelerometer_Z   -0.071738
# Gyroscope_X       -0.195164
# Gyroscope_Y        0.680448
# Gyroscope_Z        1.141301
# Patient_ID         1.000000
# Label              0.000000
# Name: 20539, dtype: float64
# Timestamp          1.599147
# Accelerometer_X   -0.508992
# Accelerometer_Y    0.289231
# Accelerometer_Z   -0.053945
# Gyroscope_X       -0.193778
# Gyroscope_Y        0.843131
# Gyroscope_Z        1.290040
# Patient_ID         1.000000
# Label              0.000000
# Name: 20540, dtype: float64
# Timestamp          1.609204
# Accelerometer_X   -0.542828
# Accelerometer_Y    0.279608
# Accelerometer_Z   -0.047150
# Gyroscope_X       -0.207380
# Gyroscope_Y        1.005812
# Gyroscope_Z        1.452603
# Patient_ID         1.000000
# Label              0.000000
# Name: 20541, dtype: float64
# Timestamp          1.619174
# Accelerometer_X   -0.573205
# Accelerometer_Y    0.280317
# Accelerometer_Z   -0.032036
# Gyroscope_X       -0.183657
# Gyroscope_Y        1.178284
# Gyroscope_Z        1.601265
# Patient_ID         1.000000
# Label              0.000000
# Name: 20542, dtype: float64
# Timestamp          1.629162
# Accelerometer_X   -0.608175
# Accelerometer_Y    0.304574
# Accelerometer_Z    0.003819
# Gyroscope_X       -0.098026
# Gyroscope_Y        1.357510
# Gyroscope_Z        1.733904
# Patient_ID         1.000000
# Label              0.000000
# Name: 20543, dtype: float64
# Timestamp          1.639175
# Accelerometer_X   -0.631091
# Accelerometer_Y    0.338346
# Accelerometer_Z    0.052628
# Gyroscope_X        0.032402
# Gyroscope_Y        1.548673
# Gyroscope_Z        1.846246
# Patient_ID         1.000000
# Label              0.000000
# Name: 20544, dtype: float64
# Timestamp          1.649223
# Accelerometer_X   -0.652503
# Accelerometer_Y    0.371929
# Accelerometer_Z    0.088806
# Gyroscope_X        0.178863
# Gyroscope_Y        1.745135
# Gyroscope_Z        1.939423
# Patient_ID         1.000000
# Label              0.000000
# Name: 20545, dtype: float64
# Timestamp          1.659254
# Accelerometer_X   -0.673225
# Accelerometer_Y    0.402594
# Accelerometer_Z    0.110297
# Gyroscope_X        0.349970
# Gyroscope_Y        1.927938
# Gyroscope_Z        2.037983
# Patient_ID         1.000000
# Label              0.000000
# Name: 20546, dtype: float64
# Timestamp          1.669140
# Accelerometer_X   -0.700049
# Accelerometer_Y    0.420769
# Accelerometer_Z    0.136496
# Gyroscope_X        0.519812
# Gyroscope_Y        2.129029
# Gyroscope_Z        2.151299
# Patient_ID         1.000000
# Label              0.000000
# Name: 20547, dtype: float64
# Timestamp          1.679185
# Accelerometer_X   -0.729276
# Accelerometer_Y    0.442345
# Accelerometer_Z    0.184731
# Gyroscope_X        0.697974
# Gyroscope_Y        2.350627
# Gyroscope_Z        2.280411
# Patient_ID         1.000000
# Label              0.000000
# Name: 20548, dtype: float64
# Timestamp          1.689536
# Accelerometer_X   -0.757855
# Accelerometer_Y    0.467247
# Accelerometer_Z    0.233346
# Gyroscope_X        0.861041
# Gyroscope_Y        2.581921
# Gyroscope_Z        2.432847
# Patient_ID         1.000000
# Label              0.000000
# Name: 20549, dtype: float64
# Timestamp          1.699356
# Accelerometer_X   -0.787275
# Accelerometer_Y    0.490449
# Accelerometer_Z    0.271538
# Gyroscope_X        0.986979
# Gyroscope_Y        2.776767
# Gyroscope_Z        2.605728
# Patient_ID         1.000000
# Label              0.000000
# Name: 20550, dtype: float64
# Timestamp          1.709317
# Accelerometer_X   -0.807827
# Accelerometer_Y    0.472447
# Accelerometer_Z    0.299720
# Gyroscope_X        0.997926
# Gyroscope_Y        2.920817
# Gyroscope_Z        2.817265
# Patient_ID         1.000000
# Label              0.000000
# Name: 20551, dtype: float64
# Timestamp          1.719269
# Accelerometer_X   -0.809981
# Accelerometer_Y    0.438708
# Accelerometer_Z    0.297796
# Gyroscope_X        0.913222
# Gyroscope_Y        3.005525
# Gyroscope_Z        3.050501
# Patient_ID         1.000000
# Label              0.000000
# Name: 20552, dtype: float64
# Timestamp          1.729428
# Accelerometer_X   -0.803314
# Accelerometer_Y    0.414175
# Accelerometer_Z    0.302085
# Gyroscope_X        0.766781
# Gyroscope_Y        3.061072
# Gyroscope_Z        3.304154
# Patient_ID         1.000000
# Label              0.000000
# Name: 20553, dtype: float64
# Timestamp          1.739312
# Accelerometer_X   -0.802309
# Accelerometer_Y    0.425861
# Accelerometer_Z    0.319472
# Gyroscope_X        0.598094
# Gyroscope_Y        3.095086
# Gyroscope_Z        3.560089
# Patient_ID         1.000000
# Label              0.000000
# Name: 20554, dtype: float64
# Timestamp          1.749309
# Accelerometer_X   -0.803495
# Accelerometer_Y    0.450380
# Accelerometer_Z    0.337584
# Gyroscope_X        0.449861
# Gyroscope_Y        3.106843
# Gyroscope_Z        3.819340
# Patient_ID         1.000000
# Label              0.000000
# Name: 20555, dtype: float64
# Timestamp          1.759439
# Accelerometer_X   -0.786634
# Accelerometer_Y    0.454217
# Accelerometer_Z    0.359807
# Gyroscope_X        0.376723
# Gyroscope_Y        3.066949
# Gyroscope_Z        4.094808
# Patient_ID         1.000000
# Label              0.000000
# Name: 20556, dtype: float64
# Timestamp          1.769259
# Accelerometer_X   -0.766980
# Accelerometer_Y    0.464300
# Accelerometer_Z    0.373145
# Gyroscope_X        0.420143
# Gyroscope_Y        3.004395
# Gyroscope_Z        4.365030
# Patient_ID         1.000000
# Label              0.000000
# Name: 20557, dtype: float64
# Timestamp          1.779240
# Accelerometer_X   -0.768079
# Accelerometer_Y    0.505924
# Accelerometer_Z    0.400277
# Gyroscope_X        0.600066
# Gyroscope_Y        2.964137
# Gyroscope_Z        4.619077
# Patient_ID         1.000000
# Label              0.000000
# Name: 20558, dtype: float64
# Timestamp          1.789270
# Accelerometer_X   -0.788778
# Accelerometer_Y    0.565950
# Accelerometer_Z    0.422164
# Gyroscope_X        0.868483
# Gyroscope_Y        2.943647
# Gyroscope_Z        4.854873
# Patient_ID         1.000000
# Label              0.000000
# Name: 20559, dtype: float64
# Timestamp          1.799249
# Accelerometer_X   -0.819956
# Accelerometer_Y    0.597029
# Accelerometer_Z    0.460095
# Gyroscope_X        1.186856
# Gyroscope_Y        2.952332
# Gyroscope_Z        5.081945
# Patient_ID         1.000000
# Label              0.000000
# Name: 20560, dtype: float64
# Timestamp          1.809271
# Accelerometer_X   -0.850188
# Accelerometer_Y    0.571524
# Accelerometer_Z    0.470067
# Gyroscope_X        1.511844
# Gyroscope_Y        2.940648
# Gyroscope_Z        5.296397
# Patient_ID         1.000000
# Label              0.000000
# Name: 20561, dtype: float64
# Timestamp          1.819261
# Accelerometer_X   -0.859053
# Accelerometer_Y    0.532233
# Accelerometer_Z    0.466572
# Gyroscope_X        1.840092
# Gyroscope_Y        2.927791
# Gyroscope_Z        5.495982
# Patient_ID         1.000000
# Label              0.000000
# Name: 20562, dtype: float64
# Timestamp          1.829254
# Accelerometer_X   -0.863107
# Accelerometer_Y    0.500036
# Accelerometer_Z    0.463859
# Gyroscope_X        2.148000
# Gyroscope_Y        2.930621
# Gyroscope_Z        5.673167
# Patient_ID         1.000000
# Label              0.000000
# Name: 20563, dtype: float64
# Timestamp          1.839290
# Accelerometer_X   -0.873283
# Accelerometer_Y    0.475045
# Accelerometer_Z    0.482334
# Gyroscope_X        2.387407
# Gyroscope_Y        2.967923
# Gyroscope_Z        5.819371
# Patient_ID         1.000000
# Label              0.000000
# Name: 20564, dtype: float64
# Timestamp          1.849232
# Accelerometer_X   -0.887703
# Accelerometer_Y    0.438687
# Accelerometer_Z    0.528145
# Gyroscope_X        2.568038
# Gyroscope_Y        3.026910
# Gyroscope_Z        5.929350
# Patient_ID         1.000000
# Label              0.000000
# Name: 20565, dtype: float64
# Timestamp          1.859244
# Accelerometer_X   -0.901569
# Accelerometer_Y    0.365920
# Accelerometer_Z    0.612267
# Gyroscope_X        2.732417
# Gyroscope_Y        3.126144
# Gyroscope_Z        6.010395
# Patient_ID         1.000000
# Label              0.000000
# Name: 20566, dtype: float64
# Timestamp          1.869233
# Accelerometer_X   -0.938248
# Accelerometer_Y    0.262346
# Accelerometer_Z    0.688914
# Gyroscope_X        2.777112
# Gyroscope_Y        3.241541
# Gyroscope_Z        6.090357
# Patient_ID         1.000000
# Label              0.000000
# Name: 20567, dtype: float64
# Timestamp          1.879231
# Accelerometer_X   -0.988674
# Accelerometer_Y    0.139272
# Accelerometer_Z    0.717554
# Gyroscope_X        2.621616
# Gyroscope_Y        3.295569
# Gyroscope_Z        6.175108
# Patient_ID         1.000000
# Label              0.000000
# Name: 20568, dtype: float64
# Timestamp          1.889208
# Accelerometer_X   -1.012993
# Accelerometer_Y   -0.027456
# Accelerometer_Z    0.718406
# Gyroscope_X        2.249014
# Gyroscope_Y        3.235384
# Gyroscope_Z        6.348929
# Patient_ID         1.000000
# Label              0.000000
# Name: 20569, dtype: float64
# Timestamp          1.899199
# Accelerometer_X   -0.976826
# Accelerometer_Y   -0.169192
# Accelerometer_Z    0.684917
# Gyroscope_X        1.748031
# Gyroscope_Y        3.067601
# Gyroscope_Z        6.555407
# Patient_ID         1.000000
# Label              0.000000
# Name: 20570, dtype: float64
# Timestamp          1.909219
# Accelerometer_X   -0.910377
# Accelerometer_Y   -0.261949
# Accelerometer_Z    0.633324
# Gyroscope_X        1.315363
# Gyroscope_Y        2.780421
# Gyroscope_Z        6.737115
# Patient_ID         1.000000
# Label              0.000000
# Name: 20571, dtype: float64
# Timestamp          1.919208
# Accelerometer_X   -0.847681
# Accelerometer_Y   -0.264658
# Accelerometer_Z    0.554325
# Gyroscope_X        1.124003
# Gyroscope_Y        2.501182
# Gyroscope_Z        6.879297
# Patient_ID         1.000000
# Label              0.000000
# Name: 20572, dtype: float64
# Timestamp          1.929169
# Accelerometer_X   -0.813841
# Accelerometer_Y   -0.207441
# Accelerometer_Z    0.472078
# Gyroscope_X        1.377909
# Gyroscope_Y        2.226004
# Gyroscope_Z        6.968020
# Patient_ID         1.000000
# Label              0.000000
# Name: 20573, dtype: float64
# Timestamp          1.939193
# Accelerometer_X   -0.811692
# Accelerometer_Y   -0.218103
# Accelerometer_Z    0.420351
# Gyroscope_X        1.767412
# Gyroscope_Y        1.966417
# Gyroscope_Z        7.007679
# Patient_ID         1.000000
# Label              0.000000
# Name: 20574, dtype: float64
# Timestamp          1.949197
# Accelerometer_X   -0.809599
# Accelerometer_Y   -0.202069
# Accelerometer_Z    0.371880
# Gyroscope_X        2.126353
# Gyroscope_Y        1.808756
# Gyroscope_Z        6.994639
# Patient_ID         1.000000
# Label              0.000000
# Name: 20575, dtype: float64
# Timestamp          1.959155
# Accelerometer_X   -0.794593
# Accelerometer_Y   -0.170989
# Accelerometer_Z    0.422840
# Gyroscope_X        2.452380
# Gyroscope_Y        1.788078
# Gyroscope_Z        6.905302
# Patient_ID         1.000000
# Label              0.000000
# Name: 20576, dtype: float64
# Timestamp          1.969247
# Accelerometer_X   -0.829272
# Accelerometer_Y   -0.198242
# Accelerometer_Z    0.469701
# Gyroscope_X        2.752081
# Gyroscope_Y        1.869448
# Gyroscope_Z        6.774952
# Patient_ID         1.000000
# Label              0.000000
# Name: 20577, dtype: float64
# Timestamp          1.979305
# Accelerometer_X   -0.902471
# Accelerometer_Y   -0.256682
# Accelerometer_Z    0.464874
# Gyroscope_X        3.034556
# Gyroscope_Y        1.974081
# Gyroscope_Z        6.631720
# Patient_ID         1.000000
# Label              0.000000
# Name: 20578, dtype: float64
# Timestamp          1.989200
# Accelerometer_X   -0.939275
# Accelerometer_Y   -0.297800
# Accelerometer_Z    0.472395
# Gyroscope_X        3.150466
# Gyroscope_Y        2.096381
# Gyroscope_Z        6.454490
# Patient_ID         1.000000
# Label              0.000000
# Name: 20579, dtype: float64
# Timestamp          1.999012
# Accelerometer_X   -0.944733
# Accelerometer_Y   -0.324936
# Accelerometer_Z    0.471569
# Gyroscope_X        3.067079
# Gyroscope_Y        2.178689
# Gyroscope_Z        6.279778
# Patient_ID         1.000000
# Label              0.000000
# Name: 20580, dtype: float64
# Timestamp          2.009150
# Accelerometer_X   -0.945915
# Accelerometer_Y   -0.391274
# Accelerometer_Z    0.473680
# Gyroscope_X        2.699567
# Gyroscope_Y        2.279189
# Gyroscope_Z        6.115775
# Patient_ID         1.000000
# Label              0.000000
# Name: 20581, dtype: float64
# Timestamp          2.019166
# Accelerometer_X   -0.979306
# Accelerometer_Y   -0.446594
# Accelerometer_Z    0.469034
# Gyroscope_X        2.077269
# Gyroscope_Y        2.324592
# Gyroscope_Z        5.989493
# Patient_ID         1.000000
# Label              0.000000
# Name: 20582, dtype: float64
# Timestamp          2.029166
# Accelerometer_X   -1.011196
# Accelerometer_Y   -0.530042
# Accelerometer_Z    0.413040
# Gyroscope_X        1.261678
# Gyroscope_Y        2.375018
# Gyroscope_Z        5.874998
# Patient_ID         1.000000
# Label              0.000000
# Name: 20583, dtype: float64
# Timestamp          2.039209
# Accelerometer_X   -1.031114
# Accelerometer_Y   -0.606690
# Accelerometer_Z    0.412148
# Gyroscope_X        0.393531
# Gyroscope_Y        2.447665
# Gyroscope_Z        5.781641
# Patient_ID         1.000000
# Label              0.000000
# Name: 20584, dtype: float64
# Timestamp          2.049162
# Accelerometer_X   -1.045084
# Accelerometer_Y   -0.617279
# Accelerometer_Z    0.396164
# Gyroscope_X       -0.428161
# Gyroscope_Y        2.443917
# Gyroscope_Z        5.712122
# Patient_ID         1.000000
# Label              0.000000
# Name: 20585, dtype: float64
# Timestamp          2.059154
# Accelerometer_X   -0.964436
# Accelerometer_Y   -0.605508
# Accelerometer_Z    0.433641
# Gyroscope_X       -1.084857
# Gyroscope_Y        2.354076
# Gyroscope_Z        5.674917
# Patient_ID         1.000000
# Label              0.000000
# Name: 20586, dtype: float64
# Timestamp          2.069136
# Accelerometer_X   -0.874197
# Accelerometer_Y   -0.602325
# Accelerometer_Z    0.442030
# Gyroscope_X       -1.441378
# Gyroscope_Y        2.237699
# Gyroscope_Z        5.637674
# Patient_ID         1.000000
# Label              0.000000
# Name: 20587, dtype: float64
# Timestamp          2.079204
# Accelerometer_X   -0.836243
# Accelerometer_Y   -0.593544
# Accelerometer_Z    0.442430
# Gyroscope_X       -1.569623
# Gyroscope_Y        2.017142
# Gyroscope_Z        5.585012
# Patient_ID         1.000000
# Label              0.000000
# Name: 20588, dtype: float64
# Timestamp          2.088999
# Accelerometer_X   -0.794407
# Accelerometer_Y   -0.562553
# Accelerometer_Z    0.363893
# Gyroscope_X       -1.396372
# Gyroscope_Y        1.746391
# Gyroscope_Z        5.514404
# Patient_ID         1.000000
# Label              0.000000
# Name: 20589, dtype: float64
# Timestamp          2.098986
# Accelerometer_X   -0.740929
# Accelerometer_Y   -0.628306
# Accelerometer_Z    0.326548
# Gyroscope_X       -1.078787
# Gyroscope_Y        1.484505
# Gyroscope_Z        5.350148
# Patient_ID         1.000000
# Label              0.000000
# Name: 20590, dtype: float64
# Timestamp          2.108989
# Accelerometer_X   -0.730372
# Accelerometer_Y   -0.675743
# Accelerometer_Z    0.309886
# Gyroscope_X       -0.677394
# Gyroscope_Y        1.187309
# Gyroscope_Z        5.105320
# Patient_ID         1.000000
# Label              0.000000
# Name: 20591, dtype: float64
# Timestamp          2.119276
# Accelerometer_X   -0.695638
# Accelerometer_Y   -0.704112
# Accelerometer_Z    0.286182
# Gyroscope_X       -0.265592
# Gyroscope_Y        0.973504
# Gyroscope_Z        4.728208
# Patient_ID         1.000000
# Label              0.000000
# Name: 20592, dtype: float64
# Timestamp          2.129002
# Accelerometer_X   -0.662492
# Accelerometer_Y   -0.765059
# Accelerometer_Z    0.329883
# Gyroscope_X       -0.022717
# Gyroscope_Y        0.814546
# Gyroscope_Z        4.293489
# Patient_ID         1.000000
# Label              0.000000
# Name: 20593, dtype: float64
# Timestamp          2.138980
# Accelerometer_X   -0.635851
# Accelerometer_Y   -0.816857
# Accelerometer_Z    0.373006
# Gyroscope_X        0.151002
# Gyroscope_Y        0.762884
# Gyroscope_Z        3.844310
# Patient_ID         1.000000
# Label              0.000000
# Name: 20594, dtype: float64
# Timestamp          2.149017
# Accelerometer_X   -0.551873
# Accelerometer_Y   -0.924793
# Accelerometer_Z    0.382187
# Gyroscope_X        0.203982
# Gyroscope_Y        0.586508
# Gyroscope_Z        3.419398
# Patient_ID         1.000000
# Label              0.000000
# Name: 20595, dtype: float64
# Timestamp          2.159168
# Accelerometer_X   -0.409275
# Accelerometer_Y   -0.955157
# Accelerometer_Z    0.382438
# Gyroscope_X        0.154681
# Gyroscope_Y        0.399431
# Gyroscope_Z        2.960630
# Patient_ID         1.000000
# Label              0.000000
# Name: 20596, dtype: float64
# Timestamp          2.168977
# Accelerometer_X   -0.334721
# Accelerometer_Y   -0.912505
# Accelerometer_Z    0.402173
# Gyroscope_X        0.057485
# Gyroscope_Y        0.204302
# Gyroscope_Z        2.478575
# Patient_ID         1.000000
# Label              0.000000
# Name: 20597, dtype: float64
# Timestamp          2.178949
# Accelerometer_X   -0.311777
# Accelerometer_Y   -0.910578
# Accelerometer_Z    0.349253
# Gyroscope_X       -0.114211
# Gyroscope_Y       -0.035894
# Gyroscope_Z        2.043610
# Patient_ID         1.000000
# Label              0.000000
# Name: 20598, dtype: float64
# Timestamp          2.188940
# Accelerometer_X   -0.255190
# Accelerometer_Y   -0.941469
# Accelerometer_Z    0.250580
# Gyroscope_X       -0.346892
# Gyroscope_Y       -0.283507
# Gyroscope_Z        1.671416
# Patient_ID         1.000000
# Label              0.000000
# Name: 20599, dtype: float64
# Timestamp          2.199178
# Accelerometer_X   -0.212601
# Accelerometer_Y   -0.927574
# Accelerometer_Z    0.190832
# Gyroscope_X       -0.579366
# Gyroscope_Y       -0.450426
# Gyroscope_Z        1.361382
# Patient_ID         1.000000
# Label              0.000000
# Name: 20600, dtype: float64
# Timestamp          2.208950
# ...
# Gyroscope_Z        0.034480
# Patient_ID         1.000000
# Label              0.000000
# Name: 21347, dtype: float64
# Timestamp          9.675638
# Accelerometer_X   -0.002883
# Accelerometer_Y    0.012366
# Accelerometer_Z   -0.003636
# Gyroscope_X       -0.002246
# Gyroscope_Y       -0.023299
# Gyroscope_Z        0.039780
# Patient_ID         1.000000
# Label              0.000000
# Name: 21348, dtype: float64
# Timestamp          9.685621
# Accelerometer_X   -0.002604
# Accelerometer_Y    0.011364
# Accelerometer_Z   -0.005559
# Gyroscope_X       -0.003307
# Gyroscope_Y       -0.023325
# Gyroscope_Z        0.037656
# Patient_ID         1.000000
# Label              0.000000
# Name: 21349, dtype: float64
# Timestamp          9.695675
# Accelerometer_X   -0.001395
# Accelerometer_Y    0.007457
# Accelerometer_Z   -0.004539
# Gyroscope_X        0.000913
# Gyroscope_Y       -0.016886
# Gyroscope_Z        0.037615
# Patient_ID         1.000000
# Label              0.000000
# Name: 21350, dtype: float64
# Timestamp          9.705677
# Accelerometer_X   -0.004154
# Accelerometer_Y    0.002594
# Accelerometer_Z   -0.000624
# Gyroscope_X        0.006229
# Gyroscope_Y       -0.012606
# Gyroscope_Z        0.033334
# Patient_ID         1.000000
# Label              0.000000
# Name: 21351, dtype: float64
# Timestamp          9.715619
# Accelerometer_X   -0.004984
# Accelerometer_Y   -0.000310
# Accelerometer_Z   -0.003550
# Gyroscope_X        0.005136
# Gyroscope_Y       -0.008365
# Gyroscope_Z        0.030119
# Patient_ID         1.000000
# Label              0.000000
# Name: 21352, dtype: float64
# Timestamp          9.725686
# Accelerometer_X   -0.003833
# Accelerometer_Y   -0.007144
# Accelerometer_Z   -0.007405
# Gyroscope_X       -0.001249
# Gyroscope_Y       -0.009511
# Gyroscope_Z        0.026944
# Patient_ID         1.000000
# Label              0.000000
# Name: 21353, dtype: float64
# Timestamp          9.735480
# Accelerometer_X   -0.003723
# Accelerometer_Y   -0.013032
# Accelerometer_Z   -0.008362
# Gyroscope_X        0.000840
# Gyroscope_Y       -0.001008
# Gyroscope_Z        0.019451
# Patient_ID         1.000000
# Label              0.000000
# Name: 21354, dtype: float64
# Timestamp          9.745609
# Accelerometer_X   -0.004775
# Accelerometer_Y   -0.010070
# Accelerometer_Z   -0.006427
# Gyroscope_X        0.008225
# Gyroscope_Y        0.012871
# Gyroscope_Z        0.010856
# Patient_ID         1.000000
# Label              0.000000
# Name: 21355, dtype: float64
# Timestamp          9.755655
# Accelerometer_X   -0.005994
# Accelerometer_Y   -0.011898
# Accelerometer_Z    0.003339
# Gyroscope_X        0.013471
# Gyroscope_Y        0.026747
# Gyroscope_Z        0.004391
# Patient_ID         1.000000
# Label              0.000000
# Name: 21356, dtype: float64
# Timestamp          9.765599
# Accelerometer_X   -0.006300
# Accelerometer_Y   -0.009834
# Accelerometer_Z    0.002327
# Gyroscope_X        0.013439
# Gyroscope_Y        0.033105
# Gyroscope_Z       -0.002025
# Patient_ID         1.000000
# Label              0.000000
# Name: 21357, dtype: float64
# Timestamp          9.775582
# Accelerometer_X   -0.003632
# Accelerometer_Y   -0.013678
# Accelerometer_Z   -0.001553
# Gyroscope_X        0.002822
# Gyroscope_Y        0.026597
# Gyroscope_Z       -0.004102
# Patient_ID         1.000000
# Label              0.000000
# Name: 21358, dtype: float64
# Timestamp          9.785554
# Accelerometer_X   -0.002921
# Accelerometer_Y   -0.013669
# Accelerometer_Z    0.000386
# Gyroscope_X       -0.001430
# Gyroscope_Y        0.026518
# Gyroscope_Z       -0.009411
# Patient_ID         1.000000
# Label              0.000000
# Name: 21359, dtype: float64
# Timestamp          9.795648
# Accelerometer_X   -0.004211
# Accelerometer_Y   -0.007843
# Accelerometer_Z    0.004249
# Gyroscope_X       -0.005665
# Gyroscope_Y        0.025349
# Gyroscope_Z       -0.016835
# Patient_ID         1.000000
# Label              0.000000
# Name: 21360, dtype: float64
# Timestamp          9.805567
# Accelerometer_X   -0.000614
# Accelerometer_Y   -0.002018
# Accelerometer_Z    0.006190
# Gyroscope_X       -0.007812
# Gyroscope_Y        0.026410
# Gyroscope_Z       -0.015778
# Patient_ID         1.000000
# Label              0.000000
# Name: 21361, dtype: float64
# Timestamp          9.815691
# Accelerometer_X   -0.000874
# Accelerometer_Y   -0.001111
# Accelerometer_Z    0.005200
# Gyroscope_X       -0.006756
# Gyroscope_Y        0.026449
# Gyroscope_Z       -0.012593
# Patient_ID         1.000000
# Label              0.000000
# Name: 21362, dtype: float64
# Timestamp          9.825603
# Accelerometer_X   -0.002197
# Accelerometer_Y    0.003762
# Accelerometer_Z    0.008083
# Gyroscope_X        0.000683
# Gyroscope_Y        0.032865
# Gyroscope_Z       -0.019015
# Patient_ID         1.000000
# Label              0.000000
# Name: 21363, dtype: float64
# Timestamp          9.835632
# Accelerometer_X   -0.001533
# Accelerometer_Y    0.008703
# Accelerometer_Z    0.004142
# Gyroscope_X        0.007149
# Gyroscope_Y        0.026481
# Gyroscope_Z       -0.021101
# Patient_ID         1.000000
# Label              0.000000
# Name: 21364, dtype: float64
# Timestamp          9.845587
# Accelerometer_X    0.000227
# Accelerometer_Y    0.006796
# Accelerometer_Z   -0.000741
# Gyroscope_X        0.002902
# Gyroscope_Y        0.021159
# Gyroscope_Z       -0.014689
# Patient_ID         1.000000
# Label              0.000000
# Name: 21365, dtype: float64
# Timestamp          9.855806
# Accelerometer_X    0.001085
# Accelerometer_Y    0.004865
# Accelerometer_Z   -0.005619
# Gyroscope_X       -0.000241
# Gyroscope_Y        0.010525
# Gyroscope_Z       -0.005055
# Patient_ID         1.000000
# Label              0.000000
# Name: 21366, dtype: float64
# Timestamp          9.865582
# Accelerometer_X    0.004922
# Accelerometer_Y    0.001969
# Accelerometer_Z   -0.005578
# Gyroscope_X       -0.002372
# Gyroscope_Y        0.008407
# Gyroscope_Z       -0.000790
# Patient_ID         1.000000
# Label              0.000000
# Name: 21367, dtype: float64
# Timestamp          9.875613
# Accelerometer_X    0.002818
# Accelerometer_Y    0.010768
# Accelerometer_Z   -0.000761
# Gyroscope_X        0.004048
# Gyroscope_Y        0.007369
# Gyroscope_Z       -0.002912
# Patient_ID         1.000000
# Label              0.000000
# Name: 21368, dtype: float64
# Timestamp          9.887896
# Accelerometer_X    0.002781
# Accelerometer_Y    0.016659
# Accelerometer_Z   -0.003723
# Gyroscope_X        0.000908
# Gyroscope_Y       -0.002229
# Gyroscope_Z        0.002464
# Patient_ID         1.000000
# Label              0.000000
# Name: 21369, dtype: float64
# Timestamp          9.895459
# Accelerometer_X    0.005793
# Accelerometer_Y    0.008878
# Accelerometer_Z   -0.004637
# Gyroscope_X       -0.001220
# Gyroscope_Y       -0.003311
# Gyroscope_Z        0.002471
# Patient_ID         1.000000
# Label              0.000000
# Name: 21370, dtype: float64
# Timestamp          9.906159
# Accelerometer_X    0.004841
# Accelerometer_Y    0.007892
# Accelerometer_Z   -0.001705
# Gyroscope_X       -0.001249
# Gyroscope_Y       -0.002188
# Gyroscope_Z        0.008838
# Patient_ID         1.000000
# Label              0.000000
# Name: 21371, dtype: float64
# Timestamp          9.916142
# Accelerometer_X    0.004866
# Accelerometer_Y    0.006829
# Accelerometer_Z   -0.003639
# Gyroscope_X       -0.015155
# Gyroscope_Y       -0.000130
# Gyroscope_Z        0.010955
# Patient_ID         1.000000
# Label              0.000000
# Name: 21372, dtype: float64
# Timestamp          9.926101
# Accelerometer_X    0.002959
# Accelerometer_Y   -0.000199
# Accelerometer_Z   -0.001666
# Gyroscope_X       -0.017313
# Gyroscope_Y        0.003050
# Gyroscope_Z        0.009873
# Patient_ID         1.000000
# Label              0.000000
# Name: 21373, dtype: float64
# Timestamp          9.935844
# Accelerometer_X    0.001937
# Accelerometer_Y    0.000636
# Accelerometer_Z   -0.000702
# Gyroscope_X       -0.013055
# Gyroscope_Y        0.005207
# Gyroscope_Z        0.008796
# Patient_ID         1.000000
# Label              0.000000
# Name: 21374, dtype: float64
# Timestamp          9.945496
# Accelerometer_X    0.001923
# Accelerometer_Y    0.000546
# Accelerometer_Z   -0.001678
# Gyroscope_X       -0.006585
# Gyroscope_Y       -0.002234
# Gyroscope_Z        0.007778
# Patient_ID         1.000000
# Label              0.000000
# Name: 21375, dtype: float64
# Timestamp          9.955296
# Accelerometer_X    0.004971
# Accelerometer_Y   -0.001469
# Accelerometer_Z   -0.006523
# Gyroscope_X       -0.004355
# Gyroscope_Y       -0.012925
# Gyroscope_Z        0.005722
# Patient_ID         1.000000
# Label              0.000000
# Name: 21376, dtype: float64
# Timestamp          9.965333
# Accelerometer_X    0.007064
# Accelerometer_Y   -0.007413
# Accelerometer_Z   -0.003538
# Gyroscope_X       -0.016173
# Gyroscope_Y       -0.004448
# Gyroscope_Z        0.007800
# Patient_ID         1.000000
# Label              0.000000
# Name: 21377, dtype: float64
# Timestamp          9.975298
# Accelerometer_X    0.005256
# Accelerometer_Y   -0.008519
# Accelerometer_Z    0.004290
# Gyroscope_X       -0.007468
# Gyroscope_Y       -0.020503
# Gyroscope_Z       -0.002726
# Patient_ID         1.000000
# Label              0.000000
# Name: 21378, dtype: float64
# Timestamp          9.985324
# Accelerometer_X    0.004391
# Accelerometer_Y   -0.006658
# Accelerometer_Z    0.003308
# Gyroscope_X       -0.006452
# Gyroscope_Y       -0.010949
# Gyroscope_Z       -0.011288
# Patient_ID         1.000000
# Label              0.000000
# Name: 21379, dtype: float64
# Timestamp          9.995382
# Accelerometer_X    0.000554
# Accelerometer_Y   -0.001925
# Accelerometer_Z    0.006186
# Gyroscope_X       -0.013867
# Gyroscope_Y       -0.018476
# Gyroscope_Z       -0.010173
# Patient_ID         1.000000
# Label              0.000000
# Name: 21380, dtype: float64
# Timestamp          10.005383
# Accelerometer_X     0.009543
# Accelerometer_Y    -0.002927
# Accelerometer_Z     0.002370
# Gyroscope_X        -0.002129
# Gyroscope_Y        -0.018376
# Gyroscope_Z        -0.009119
# Patient_ID          1.000000
# Label               0.000000
# Name: 21381, dtype: float64
# Timestamp          10.015363
# Accelerometer_X     0.004729
# Accelerometer_Y     0.006792
# Accelerometer_Z     0.003263
# Gyroscope_X         0.002125
# Gyroscope_Y        -0.015165
# Gyroscope_Z        -0.012330
# Patient_ID          1.000000
# Label               0.000000
# Name: 21382, dtype: float64
# Timestamp          10.025447
# Accelerometer_X     0.004910
# Accelerometer_Y     0.002893
# Accelerometer_Z     0.005241
# Gyroscope_X        -0.001061
# Gyroscope_Y        -0.018369
# Gyroscope_Z        -0.009120
# Patient_ID          1.000000
# Label               0.000000
# Name: 21383, dtype: float64
# Timestamp          10.035366
# Accelerometer_X     0.007112
# Accelerometer_Y    -0.000098
# Accelerometer_Z     0.003332
# Gyroscope_X        -0.012776
# Gyroscope_Y        -0.022710
# Gyroscope_Z        -0.005895
# Patient_ID          1.000000
# Label               0.000000
# Name: 21384, dtype: float64
# Timestamp          10.045491
# Accelerometer_X     0.000530
# Accelerometer_Y    -0.005193
# Accelerometer_Z     0.000388
# Gyroscope_X        -0.019196
# Gyroscope_Y        -0.019581
# Gyroscope_Z        -0.009098
# Patient_ID          1.000000
# Label               0.000000
# Name: 21385, dtype: float64
# Timestamp          10.055500
# Accelerometer_X    -0.003240
# Accelerometer_Y    -0.005375
# Accelerometer_Z    -0.000608
# Gyroscope_X        -0.008616
# Gyroscope_Y        -0.006706
# Gyroscope_Z        -0.013440
# Patient_ID          1.000000
# Label               0.000000
# Name: 21386, dtype: float64
# Timestamp          10.065487
# Accelerometer_X    -0.005295
# Accelerometer_Y     0.005342
# Accelerometer_Z     0.000292
# Gyroscope_X         0.006231
# Gyroscope_Y         0.007257
# Gyroscope_Z        -0.018853
# Patient_ID          1.000000
# Label               0.000000
# Name: 21387, dtype: float64
# Timestamp          10.075450
# Accelerometer_X    -0.009352
# Accelerometer_Y     0.008316
# Accelerometer_Z    -0.000741
# Gyroscope_X         0.013610
# Gyroscope_Y         0.018017
# Gyroscope_Z        -0.016801
# Patient_ID          1.000000
# Label               0.000000
# Name: 21388, dtype: float64
# Timestamp          10.085518
# Accelerometer_X    -0.008585
# Accelerometer_Y     0.004571
# Accelerometer_Z     0.000248
# Gyroscope_X         0.015716
# Gyroscope_Y         0.022290
# Gyroscope_Z        -0.018955
# Patient_ID          1.000000
# Label               0.000000
# Name: 21389, dtype: float64
# Timestamp          10.095502
# Accelerometer_X    -0.007841
# Accelerometer_Y     0.003706
# Accelerometer_Z    -0.000730
# Gyroscope_X         0.008251
# Gyroscope_Y         0.020123
# Gyroscope_Z        -0.015749
# Patient_ID          1.000000
# Label               0.000000
# Name: 21390, dtype: float64
# Timestamp          10.105471
# Accelerometer_X    -0.006042
# Accelerometer_Y     0.000790
# Accelerometer_Z    -0.001687
# Gyroscope_X        -0.001298
# Gyroscope_Y         0.012577
# Gyroscope_Z        -0.014631
# Patient_ID          1.000000
# Label               0.000000
# Name: 21391, dtype: float64
# Timestamp          10.115488
# Accelerometer_X    -0.006065
# Accelerometer_Y    -0.005119
# Accelerometer_Z    -0.005567
# Gyroscope_X        -0.000169
# Gyroscope_Y         0.006152
# Gyroscope_Z        -0.016714
# Patient_ID          1.000000
# Label               0.000000
# Name: 21392, dtype: float64
# Timestamp          10.125485
# Accelerometer_X    -0.007220
# Accelerometer_Y     0.004684
# Accelerometer_Z    -0.002705
# Gyroscope_X         0.010506
# Gyroscope_Y         0.009369
# Gyroscope_Z        -0.025241
# Patient_ID          1.000000
# Label               0.000000
# Name: 21393, dtype: float64
# Timestamp          10.135481
# Accelerometer_X    -0.007408
# Accelerometer_Y     0.006813
# Accelerometer_Z     0.003142
# Gyroscope_X         0.021126
# Gyroscope_Y         0.016914
# Gyroscope_Z        -0.027422
# Patient_ID          1.000000
# Label               0.000000
# Name: 21394, dtype: float64
# Timestamp          10.145468
# Accelerometer_X    -0.004652
# Accelerometer_Y     0.004070
# Accelerometer_Z     0.005111
# Gyroscope_X         0.011516
# Gyroscope_Y         0.016849
# Gyroscope_Z        -0.026353
# Patient_ID          1.000000
# Label               0.000000
# Name: 21395, dtype: float64
# Timestamp          10.155470
# Accelerometer_X    -0.002802
# Accelerometer_Y     0.000211
# Accelerometer_Z     0.003194
# Gyroscope_X        -0.002387
# Gyroscope_Y         0.016809
# Gyroscope_Z        -0.018908
# Patient_ID          1.000000
# Label               0.000000
# Name: 21396, dtype: float64
# Timestamp          10.165481
# Accelerometer_X    -0.000846
# Accelerometer_Y    -0.007646
# Accelerometer_Z     0.002262
# Gyroscope_X        -0.007587
# Gyroscope_Y        -0.000323
# Gyroscope_Z        -0.017731
# Patient_ID          1.000000
# Label               0.000000
# Name: 21397, dtype: float64
# Timestamp          10.175468
# Accelerometer_X     0.003036
# Accelerometer_Y    -0.001872
# Accelerometer_Z     0.003244
# Gyroscope_X        -0.012850
# Gyroscope_Y        -0.008924
# Gyroscope_Z        -0.018734
# Patient_ID          1.000000
# Label               0.000000
# Name: 21398, dtype: float64
# Timestamp          10.185437
# Accelerometer_X     0.001216
# Accelerometer_Y    -0.002975
# Accelerometer_Z     0.003254
# Gyroscope_X        -0.007474
# Gyroscope_Y        -0.013167
# Gyroscope_Z        -0.019772
# Patient_ID          1.000000
# Label               0.000000
# Name: 21399, dtype: float64
# Timestamp          10.195432
# Accelerometer_X     0.002255
# Accelerometer_Y     0.001852
# Accelerometer_Z     0.003247
# Gyroscope_X        -0.005365
# Gyroscope_Y        -0.010989
# Gyroscope_Z        -0.016599
# Patient_ID          1.000000
# Label               0.000000
# Name: 21400, dtype: float64
# Timestamp          10.205442
# Accelerometer_X     0.003365
# Accelerometer_Y     0.001779
# Accelerometer_Z     0.001302
# Gyroscope_X        -0.006427
# Gyroscope_Y        -0.012057
# Gyroscope_Z        -0.015529
# Patient_ID          1.000000
# Label               0.000000
# Name: 21401, dtype: float64
# Timestamp          10.215447
# Accelerometer_X     0.001560
# Accelerometer_Y    -0.000262
# Accelerometer_Z     0.000336
# Gyroscope_X        -0.004265
# Gyroscope_Y        -0.013159
# Gyroscope_Z        -0.021900
# Patient_ID          1.000000
# Label               0.000000
# Name: 21402, dtype: float64
# Timestamp          10.225438
# Accelerometer_X     0.004596
# Accelerometer_Y     0.003613
# Accelerometer_Z     0.000345
# Gyroscope_X         0.001074
# Gyroscope_Y        -0.014169
# Gyroscope_Z        -0.019772
# Patient_ID          1.000000
# Label               0.000000
# Name: 21403, dtype: float64
